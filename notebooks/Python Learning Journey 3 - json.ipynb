# %%
import json

stok = {
 "kopi": 10,
 "gula": 5,
 "susu": 3
}

with open("test_db.json", "w") as f:
    json.dump(stok,f, indent=4)

with open("test_db.json","r") as f:
    data = json.load(f)

print(json.dumps(data,indent=4))

# %%
#Buat file Python kecil dengan:
#1️⃣ fungsi load_db()
#2️⃣ fungsi save_db(data)
#Lalu test seperti ini:

#db = load_db()

#db["kopi"] = {"stok":10,"min":3}

#save_db(db)
##Target:
#"WMS_db.json otomatis dibuat"



print("\n=== Mini Task V2 ===")

import json
import os

db = "../database/WMS_DB.json"

def load_db():

    if os.path.exists(db):

        with open(db,"r") as kl:
            return json.load(kl)

    else:
        return {}

def save_db(data):

    with open(db,"w") as f:
        json.dump(data,f,indent=4)

data2 = load_db()

data2["kopi"] = {"stok":10,"min":3}

print(data2)

save_db(data2)

print(f"{os.path.basename(db)} Berhasil Disimpan!")
# Out:
# === Mini Task V2 ===
# {'kopi': {'stok': 10, 'min': 3}}
# WMS_DB.json Berhasil Disimpan!
